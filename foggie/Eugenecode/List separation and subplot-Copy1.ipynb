# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib as plt
import math
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd
import statistics

data = open('MCADATA3.txt')
data1 = data.read().split()
print(data1)
e_values = []
A_values = []
B_values = []
C_values = []
D_values = []
E_values = []

valid = True
index = 0 

print(data1)

while index < (len(data1)-1):
    try:
        e_values.append(float(data1[index]))
        A_values.append(float(data1[index+1]))
        B_values.append(float(data1[index+2]))
        C_values.append(float(data1[index+3]))
        D_values.append(float(data1[index+4]))
        E_values.append(float(data1[index+5]))    
        index +=6
    except:
        break
print(e_values)    
    
edata = np.array(e_values)
A = np.array(A_values)
B = np.array(B_values)
C = np.array(C_values)
D = np.array(D_values)
E = np.array(E_values)

print(len(A))
print(type(A))
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1)
fig.suptitle('Energy Distribution from 5 Channels')
plt.xlabel('Energy Scale [Arbitary Unit]', fontsize=15)
ax1.plot(edata, A, 'o')
#ax1.set_xlabel('Energy')
#ax1.set_ylabel('Energy Count [Counts]')

ax2.plot(edata, B, 'o')
#ax2.set_xlabel('Energy')
#ax2.set_ylabel('Energy Count [Counts]')

ax3.plot(edata, A, 'o')
#ax3.set_xlabel('Energy')
ax3.set_ylabel('Energy Count [Counts]', fontsize = 15)

ax4.plot(edata, A, 'o')
#ax4.set_xlabel('Energy')
#ax4.set_ylabel('Energy Count [Counts]')

ax5.plot(edata, A, 'o')
#ax5.set_xlabel('Energy')
#ax5.set_ylabel('Energy Count [Counts]')
# Out:
# ['5', '3481', '2600', '2481', '2567', '2566', '10', '2605', '2634', '2783', '2869', '2967', '15', '2870', '2790', '2701', '2695', '2745', '20', '2717', '2840', '2893', '2766', '2924', '25', '2931', '2933', '2978', '2989', '2925', '30', '2990', '3063', '3114', '3168', '3292', '35', '3499', '3909', '4323', '4821', '4914', '40', '4927', '4666', '4429', '4216', '4086', '45', '3776', '3500', '3293', '3360', '3138', '50', '3142', '3055', '2955', '2993', '2865', '55', '2824', '2719', '2692', '2606', '2691', '60', '2525', '2503', '2388', '2431', '2477', '65', '2385', '2439', '2424', '2442', '2324', '70', '2381', '2253', '2320', '2188', '2251', '75', '2287', '2331', '2199', '2295', '2248', '80', '2195', '2240', '2207', '2130', '2156', '85', '2178', '2249', '2216', '2174', '2170', '90', '2186', '2165', '2190', '2222', '2127', '95', '2133', '2187', '2108', '2134', '2219', '100', '2161', '2261', '2209', '2141', '2233', '105', '2324', '2226', '2152', '2302', '2223', '110', '2352', '2277', '2285',
# ...
